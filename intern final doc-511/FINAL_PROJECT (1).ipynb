# %% [markdown]
# # DATA SCIENCE AND MACHINE LEARNING INTERNSHIP

# %% [markdown]
# # FINAL PROJECT:

# %% [markdown]
# ### Mobile phone price fixed on the various factors like processor, RAM,Internal memory etc There are 21 features given in the dataset.Classify the mobile price range as 0,1,2 or 3 based upon the features given in the dataset.

# %% [markdown]
# ### Class 0 – low cost
# ### Class 1 – medium cost
# ### Class 2 - high cost
# ### Class 3 – very high cost

# %% [markdown]
# ### SVM algorithm(Support vector machine)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

# %%
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
test
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %% [markdown]
# ### Data preprocessing

# %%
train.describe().transpose()
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %% [markdown]
# ### checking if there are any missing values:

# %%
train.isnull()
# Out:
#       battery_power   blue  clock_speed  dual_sim     fc  four_g  int_memory  \
# 0             False  False        False     False  False   False       False
# 1             False  False        False     False  False   False       False
# 2             False  False        False     False  False   False       False
# 3             False  False        False     False  False   False       False
# 4             False  False        False     False  False   False       False
# ...             ...    ...          ...       ...    ...     ...         ...
# 1995          False  False        False     False  False   False       False
# 1996          False  False        False     False  False   False       False
# 1997          False  False        False     False  False   False       False
# 1998          False  False        False     False  False   False       False
# 1999          False  False        False     False  False   False       False
#
# ...

# %%
test.isnull()
# Out:
#         id  battery_power   blue  clock_speed  dual_sim     fc  four_g  \
# 0    False          False  False        False     False  False   False
# 1    False          False  False        False     False  False   False
# 2    False          False  False        False     False  False   False
# 3    False          False  False        False     False  False   False
# 4    False          False  False        False     False  False   False
# ..     ...            ...    ...          ...       ...    ...     ...
# 995  False          False  False        False     False  False   False
# 996  False          False  False        False     False  False   False
# 997  False          False  False        False     False  False   False
# 998  False          False  False        False     False  False   False
# 999  False          False  False        False     False  False   False
#
#      int_memory  m_dep  mobile_wt  ...     pc  px_height  px_width    ram  \
# ...

# %% [markdown]
# ### checking if there are any duplicate values:

# %%
train.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
test.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# ### In train.csv the px_height column has irrevalent data so we replace px_height column values with their mean values

# %%
print(train['px_height'].all())
# Out:
# False

# %%
train['px_height'].replace(0, train['px_height'].mean(), inplace=True)

# %%
print(train['px_height'].all())
# Out:
# True

# %%
train.all()
# Out:
# battery_power     True
# blue             False
# clock_speed       True
# dual_sim         False
# fc               False
# four_g           False
# int_memory        True
# m_dep             True
# mobile_wt         True
# n_cores           True
# pc               False
# px_height         True
# px_width          True
# ram               True
# sc_h              True
# sc_w             False
# talk_time         True
# three_g          False
# touch_screen     False
# wifi             False
# price_range      False
# dtype: bool

# %% [markdown]
# ### checking correlation between the columns

# %%
train.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.015337 -0.006865    -0.013597 -0.022381 -0.009769
# ...

# %%
(train.corr()["price_range"]* 100).sort_values(ascending=False)
# Out:
# price_range      100.000000
# ram               91.704574
# battery_power     20.072261
# px_width          16.581750
# px_height         14.966627
# int_memory         4.443496
# sc_w               3.871127
# pc                 3.359930
# three_g            2.361122
# sc_h               2.298607
# fc                 2.199821
# talk_time          2.185887
# blue               2.057285
# wifi               1.878481
# dual_sim           1.744448
# four_g             1.477171
# n_cores            0.439927
# m_dep              0.085304
# clock_speed       -0.660569
# mobile_wt         -3.030217
# touch_screen      -3.041107
# Name: price_range, dtype: float64

# %% [markdown]
# ### as the correlation of some parameters are very low they can be ignored or dropped because they are not much useful for the prediction process

# %%
train.drop(labels=['blue', 'dual_sim', 'm_dep', 'mobile_wt','four_g', 'talk_time', 'clock_speed','touch_screen','n_cores'], inplace=True, axis=1)

# %%
train.all()
# Out:
# battery_power     True
# fc               False
# int_memory        True
# pc               False
# px_height         True
# px_width          True
# ram               True
# sc_h              True
# sc_w             False
# three_g          False
# wifi             False
# price_range      False
# dtype: bool

# %% [markdown]
# ### as there are irrelevent values in above columns replace them with mean values

# %%
train['pc'].replace(0, train['pc'].mean(), inplace=True)

# %%
train['sc_w'].replace(0, train['sc_w'].mean(), inplace=True)

# %%
train['three_g'].replace(0, train['three_g'].mean(), inplace=True)

# %%
train['wifi'].replace(0, train['wifi'].mean(), inplace=True)

# %%
train['fc'].replace(0, train['fc'].mean(), inplace=True)

# %%
train.all()
# Out:
# battery_power     True
# fc                True
# int_memory        True
# pc                True
# px_height         True
# px_width          True
# ram               True
# sc_h              True
# sc_w              True
# three_g           True
# wifi              True
# price_range      False
# dtype: bool

# %%
x_train=train

# %%
x_train.shape
# Out:
# (2000, 12)

# %%
x_train.head()
# Out:
#    battery_power       fc  int_memory    pc  px_height  px_width   ram  sc_h  \
# 0            842   1.0000           7   2.0       20.0       756  2549     9
# 1           1021   4.3095          53   6.0      905.0      1988  2631    17
# 2            563   2.0000          41   6.0     1263.0      1716  2603    11
# 3            615   4.3095          10   9.0     1216.0      1786  2769    16
# 4           1821  13.0000          44  14.0     1208.0      1212  1411     8
#
#    sc_w  three_g   wifi  price_range
# 0   7.0   0.7615  1.000            1
# 1   3.0   1.0000  0.507            2
# 2   2.0   1.0000  0.507            2
# 3   8.0   1.0000  0.507            2
# 4   2.0   1.0000  0.507            1

# %% [markdown]
# ## Y_TRAIN

# %% [markdown]
# ### as there is a price_range column in y_train(which is the predicted column) that should be dropped from trained data set

# %%
y_train = train['price_range']
train.drop(['price_range'], inplace=True, axis=1)

# %%
y_train.shape
# Out:
# (2000,)

# %%
y_train=pd.DataFrame(y_train)

# %%
y_train.head()
# Out:
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %% [markdown]
# ## X_TRAIN

# %% [markdown]
# ### after dropping price_range column remaining data should be placed in the x_train

# %%
x_train=train

# %%
x_train.shape
# Out:
# (2000, 11)

# %%
x_train.head()
# Out:
#    battery_power       fc  int_memory    pc  px_height  px_width   ram  sc_h  \
# 0            842   1.0000           7   2.0       20.0       756  2549     9
# 1           1021   4.3095          53   6.0      905.0      1988  2631    17
# 2            563   2.0000          41   6.0     1263.0      1716  2603    11
# 3            615   4.3095          10   9.0     1216.0      1786  2769    16
# 4           1821  13.0000          44  14.0     1208.0      1212  1411     8
#
#    sc_w  three_g   wifi
# 0   7.0   0.7615  1.000
# 1   3.0   1.0000  0.507
# 2   2.0   1.0000  0.507
# 3   8.0   1.0000  0.507
# 4   2.0   1.0000  0.507

# %% [markdown]
# ### as id column is not required for prediction process we drop that column

# %%
ids= test['id'] 
test.drop('id', inplace=True, axis=1)

# %%
test.all()
# Out:
# battery_power     True
# blue             False
# clock_speed       True
# dual_sim         False
# fc               False
# four_g           False
# int_memory        True
# m_dep             True
# mobile_wt         True
# n_cores           True
# pc               False
# px_height        False
# px_width          True
# ram               True
# sc_h              True
# sc_w             False
# talk_time         True
# three_g          False
# touch_screen     False
# wifi             False
# dtype: bool

# %% [markdown]
# ### as the correlation of some parameters are very low they can be ignored or dropped because they are not much useful for the prediction process

# %%
test.drop(labels=['blue', 'dual_sim', 'm_dep', 'mobile_wt','four_g', 'talk_time', 'clock_speed','touch_screen','n_cores'], inplace=True, axis=1)

# %%
test.shape
# Out:
# (1000, 11)

# %%
test.all()
# Out:
# battery_power     True
# fc               False
# int_memory        True
# pc               False
# px_height        False
# px_width          True
# ram               True
# sc_h              True
# sc_w             False
# three_g          False
# wifi             False
# dtype: bool

# %%
test['px_height'].replace(0, test['px_height'].mean(), inplace=True)
test['pc'].replace(0, test['pc'].mean(), inplace=True)
test['sc_w'].replace(0, test['sc_w'].mean(), inplace=True)
test['three_g'].replace(0, test['three_g'].mean(), inplace=True)
test['wifi'].replace(0, test['wifi'].mean(), inplace=True)
test['fc'].replace(0, test['fc'].mean(), inplace=True)

# %% [markdown]
# ### as there are irrelevent values in above columns replace them with mean values

# %%
test.all()
# Out:
# battery_power    True
# fc               True
# int_memory       True
# pc               True
# px_height        True
# px_width         True
# ram              True
# sc_h             True
# sc_w             True
# three_g          True
# wifi             True
# dtype: bool

# %% [markdown]
# ## X_TEST

# %% [markdown]
# ### After dropping the certain columns in the test dataset put the remaining columns into x_test

# %%
x_test=test

# %%
x_test.shape
# Out:
# (1000, 11)

# %% [markdown]
# ## Applying SVM algorithm to the given data set to predict values for test data set (as svm alogorithm is the best approach)

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='linear',random_state=0)
classifier.fit(x_train,y_train['price_range'])
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred=classifier.predict(x_test)

# %% [markdown]
# ### predicted values for test data set

# %%
y_pred
# Out:
# array([3, 3, 3, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 2, 1, 3,
#        1, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 1, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 1, 3, 1, 1, 3, 3, 3, 0, 1, 1, 1,
#        2, 3, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 2, 3, 0, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 2, 2, 1, 2, 2, 0, 2, 1, 2, 1, 0, 0, 3, 0, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 2, 3, 0, 0, 3, 2, 1, 2, 0, 3, 2, 3, 2, 0, 2,
#        1, 1, 3, 1, 1, 0, 3, 2, 1, 2, 1, 3, 2, 3, 3, 3, 2, 3, 2, 3, 1, 0,
#        3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 1, 0, 3, 0, 0, 0, 2, 1, 0, 1,
#        0, 0, 1, 2, 1, 0, 0, 1, 1, 2, 2, 1, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2,
#        2, 3, 1, 1, 3, 2, 3, 2, 2, 1, 0, 0, 1, 3, 0, 2, 3, 3, 0, 2, 0, 3,
#        2, 3, 3, 1, 0, 1, 0, 3, 0, 1, 0, 2, 2, 1, 2, 1, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 3, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 1, 3, 2, 1, 2,
#        3, 3, 3, 1, 0, 0, 2, 3, 1, 1, 3, 2, 0, 3, 0, 0, 3, 1, 0, 3, 2, 3,
# ...

# %%
y_pred=pd.DataFrame(y_pred)

# %%
y_pred
# Out:
#      0
# 0    3
# 1    3
# 2    3
# 3    3
# 4    1
# ..  ..
# 995  2
# 996  1
# 997  0
# 998  2
# 999  2
#
# [1000 rows x 1 columns]
